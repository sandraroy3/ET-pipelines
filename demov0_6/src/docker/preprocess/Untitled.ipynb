# %%
from sklearn import datasets

# %%
X, y = datasets.load_iris(return_X_y=True)
X
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2],
#        [5.4, 3.9, 1.7, 0.4],
#        [4.6, 3.4, 1.4, 0.3],
#        [5. , 3.4, 1.5, 0.2],
#        [4.4, 2.9, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.1],
#        [5.4, 3.7, 1.5, 0.2],
#        [4.8, 3.4, 1.6, 0.2],
#        [4.8, 3. , 1.4, 0.1],
#        [4.3, 3. , 1.1, 0.1],
#        [5.8, 4. , 1.2, 0.2],
#        [5.7, 4.4, 1.5, 0.4],
#        [5.4, 3.9, 1.3, 0.4],
#        [5.1, 3.5, 1.4, 0.3],
#        [5.7, 3.8, 1.7, 0.3],
#        [5.1, 3.8, 1.5, 0.3],
#        [5.4, 3.4, 1.7, 0.2],
#        [5.1, 3.7, 1.5, 0.4],
#        [4.6, 3.6, 1. , 0.2],
#        [5.1, 3.3, 1.7, 0.5],
#        [4.8, 3.4, 1.9, 0.2],
#        [5. , 3. , 1.6, 0.2],
#        [5. , 3.4, 1.6, 0.4],
#        [5.2, 3.5, 1.5, 0.2],
#        [5.2, 3.4, 1.4, 0.2],
#        [4.7, 3.2, 1.6, 0.2],
#        [4.8, 3.1, 1.6, 0.2],
#        [5.4, 3.4, 1.5, 0.4],
#        [5.2, 4.1, 1.5, 0.1],
#        [5.5, 4.2, 1.4, 0.2],
#        [4.9, 3.1, 1.5, 0.2],
#        [5. , 3.2, 1.2, 0.2],
#        [5.5, 3.5, 1.3, 0.2],
#        [4.9, 3.6, 1.4, 0.1],
#        [4.4, 3. , 1.3, 0.2],
#        [5.1, 3.4, 1.5, 0.2],
#        [5. , 3.5, 1.3, 0.3],
#        [4.5, 2.3, 1.3, 0.3],
#        [4.4, 3.2, 1.3, 0.2],
#        [5. , 3.5, 1.6, 0.6],
#        [5.1, 3.8, 1.9, 0.4],
#        [4.8, 3. , 1.4, 0.3],
#        [5.1, 3.8, 1.6, 0.2],
#        [4.6, 3.2, 1.4, 0.2],
#        [5.3, 3.7, 1.5, 0.2],
#        [5. , 3.3, 1.4, 0.2],
#        [7. , 3.2, 4.7, 1.4],
#        [6.4, 3.2, 4.5, 1.5],
#        [6.9, 3.1, 4.9, 1.5],
#        [5.5, 2.3, 4. , 1.3],
#        [6.5, 2.8, 4.6, 1.5],
#        [5.7, 2.8, 4.5, 1.3],
#        [6.3, 3.3, 4.7, 1.6],
#        [4.9, 2.4, 3.3, 1. ],
#        [6.6, 2.9, 4.6, 1.3],
#        [5.2, 2.7, 3.9, 1.4],
#        [5. , 2. , 3.5, 1. ],
#        [5.9, 3. , 4.2, 1.5],
#        [6. , 2.2, 4. , 1. ],
#        [6.1, 2.9, 4.7, 1.4],
#        [5.6, 2.9, 3.6, 1.3],
#        [6.7, 3.1, 4.4, 1.4],
#        [5.6, 3. , 4.5, 1.5],
#        [5.8, 2.7, 4.1, 1. ],
#        [6.2, 2.2, 4.5, 1.5],
#        [5.6, 2.5, 3.9, 1.1],
#        [5.9, 3.2, 4.8, 1.8],
#        [6.1, 2.8, 4. , 1.3],
#        [6.3, 2.5, 4.9, 1.5],
#        [6.1, 2.8, 4.7, 1.2],
#        [6.4, 2.9, 4.3, 1.3],
#        [6.6, 3. , 4.4, 1.4],
#        [6.8, 2.8, 4.8, 1.4],
#        [6.7, 3. , 5. , 1.7],
#        [6. , 2.9, 4.5, 1.5],
#        [5.7, 2.6, 3.5, 1. ],
#        [5.5, 2.4, 3.8, 1.1],
#        [5.5, 2.4, 3.7, 1. ],
#        [5.8, 2.7, 3.9, 1.2],
#        [6. , 2.7, 5.1, 1.6],
#        [5.4, 3. , 4.5, 1.5],
#        [6. , 3.4, 4.5, 1.6],
#        [6.7, 3.1, 4.7, 1.5],
#        [6.3, 2.3, 4.4, 1.3],
#        [5.6, 3. , 4.1, 1.3],
#        [5.5, 2.5, 4. , 1.3],
#        [5.5, 2.6, 4.4, 1.2],
#        [6.1, 3. , 4.6, 1.4],
#        [5.8, 2.6, 4. , 1.2],
#        [5. , 2.3, 3.3, 1. ],
#        [5.6, 2.7, 4.2, 1.3],
#        [5.7, 3. , 4.2, 1.2],
#        [5.7, 2.9, 4.2, 1.3],
#        [6.2, 2.9, 4.3, 1.3],
#        [5.1, 2.5, 3. , 1.1],
#        [5.7, 2.8, 4.1, 1.3],
#        [6.3, 3.3, 6. , 2.5],
#        [5.8, 2.7, 5.1, 1.9],
#        [7.1, 3. , 5.9, 2.1],
#        [6.3, 2.9, 5.6, 1.8],
#        [6.5, 3. , 5.8, 2.2],
#        [7.6, 3. , 6.6, 2.1],
#        [4.9, 2.5, 4.5, 1.7],
#        [7.3, 2.9, 6.3, 1.8],
#        [6.7, 2.5, 5.8, 1.8],
#        [7.2, 3.6, 6.1, 2.5],
#        [6.5, 3.2, 5.1, 2. ],
#        [6.4, 2.7, 5.3, 1.9],
#        [6.8, 3. , 5.5, 2.1],
#        [5.7, 2.5, 5. , 2. ],
#        [5.8, 2.8, 5.1, 2.4],
#        [6.4, 3.2, 5.3, 2.3],
#        [6.5, 3. , 5.5, 1.8],
#        [7.7, 3.8, 6.7, 2.2],
#        [7.7, 2.6, 6.9, 2.3],
#        [6. , 2.2, 5. , 1.5],
#        [6.9, 3.2, 5.7, 2.3],
#        [5.6, 2.8, 4.9, 2. ],
#        [7.7, 2.8, 6.7, 2. ],
#        [6.3, 2.7, 4.9, 1.8],
#        [6.7, 3.3, 5.7, 2.1],
#        [7.2, 3.2, 6. , 1.8],
#        [6.2, 2.8, 4.8, 1.8],
#        [6.1, 3. , 4.9, 1.8],
#        [6.4, 2.8, 5.6, 2.1],
#        [7.2, 3. , 5.8, 1.6],
#        [7.4, 2.8, 6.1, 1.9],
#        [7.9, 3.8, 6.4, 2. ],
#        [6.4, 2.8, 5.6, 2.2],
#        [6.3, 2.8, 5.1, 1.5],
#        [6.1, 2.6, 5.6, 1.4],
#        [7.7, 3. , 6.1, 2.3],
#        [6.3, 3.4, 5.6, 2.4],
#        [6.4, 3.1, 5.5, 1.8],
#        [6. , 3. , 4.8, 1.8],
#        [6.9, 3.1, 5.4, 2.1],
#        [6.7, 3.1, 5.6, 2.4],
#        [6.9, 3.1, 5.1, 2.3],
#        [5.8, 2.7, 5.1, 1.9],
#        [6.8, 3.2, 5.9, 2.3],
#        [6.7, 3.3, 5.7, 2.5],
#        [6.7, 3. , 5.2, 2.3],
#        [6.3, 2.5, 5. , 1.9],
#        [6.5, 3. , 5.2, 2. ],
#        [6.2, 3.4, 5.4, 2.3],
#        [5.9, 3. , 5.1, 1.8]])

# %%
# !pip list
# Out:
# Package                       Version
# ----------------------------- ----------------------------
# absl-py                       0.11.0
# adal                          1.2.7
# alabaster                     0.7.12
# aniso8601                     9.0.1
# argon2-cffi                   20.1.0
# astor                         0.8.1
# async-generator               1.10
# attrs                         20.3.0
# autopep8                      1.4.4
# azure-common                  1.1.27
# azure-storage-blob            2.1.0
# azure-storage-common          2.1.0
# Babel                         2.9.0
# backcall                      0.2.0
# bleach                        3.3.0
# cachetools                    4.2.1
# certifi                       2020.12.5
# cffi                          1.14.5
# chardet                       4.0.0
# click                         7.1.2
# cloudpickle                   1.6.0
# configobj                     5.0.6
# crcmod                        1.7
# cryptography                  3.4.7
# decorator                     4.4.2
# deepdiff                      3.3.0
# defusedxml                    0.7.1
# Deprecated                    1.2.12
# dill                          0.3.3
# dnspython                     2.1.0
# docstring-parser              0.7.3
# docutils                      0.16
# entrypoints                   0.3
# fire                          0.4.0
# google-api-core               1.26.3
# google-api-python-client      1.12.8
# google-auth                   1.29.0
# google-auth-httplib2          0.1.0
# google-cloud-core             1.6.0
# google-cloud-storage          1.37.1
# google-crc32c                 1.1.2
# google-resumable-media        1.2.0
# googleapis-common-protos      1.53.0
# grpcio                        1.37.0
# httplib2                      0.19.1
# idna                          2.10
# imagesize                     1.2.0
# importlib-metadata            3.10.0
# ipykernel                     5.5.3
# ipython                       7.16.1
# ipython-genutils              0.2.0
# ipywidgets                    7.6.3
# jedi                          0.18.0
# Jinja2                        2.11.3
# joblib                        1.0.1
# json5                         0.9.5
# jsonpickle                    2.0.0
# jsonschema                    3.2.0
# jupyter-client                6.1.12
# jupyter-core                  4.7.1
# jupyterlab                    2.3.1
# jupyterlab-pygments           0.1.2
# jupyterlab-server             1.2.0
# jupyterlab-widgets            1.0.0
# kfp                           1.6.3
# kfp-pipeline-spec             0.1.8
# kfp-server-api                1.5.0
# kfserving                     0.4.1
# kubeflow-kale                 0.6.0
# kubernetes                    10.0.1
# latexcodec                    2.0.1
# lockfile                      0.12.2
# MarkupSafe                    1.1.1
# minio                         7.0.3
# mistune                       0.8.4
# ml-metadata                   0.30.0
# monotonic                     1.6
# nbclient                      0.5.3
# nbconvert                     5.6.1
# nbformat                      4.4.0
# nest-asyncio                  1.5.1
# networkx                      2.5.1
# notebook                      6.3.0
# numpy                         1.19.5
# oauthlib                      3.1.0
# packaging                     20.9
# pandocfilters                 1.4.3
# parso                         0.8.2
# pexpect                       4.8.0
# pickleshare                   0.7.5
# pip                           21.0.1
# prettytable                   2.1.0
# progress                      1.5
# prometheus-client             0.9.0
# prompt-toolkit                3.0.18
# protobuf                      3.15.8
# psutil                        5.8.0
# ptyprocess                    0.7.0
# pyasn1                        0.4.8
# pyasn1-modules                0.2.8
# pybtex                        0.24.0
# pycodestyle                   2.7.0
# pycparser                     2.20
# pyflakes                      2.3.1
# Pygments                      2.8.1
# PyJWT                         2.0.1
# pyparsing                     2.4.7
# Pyro4                         4.80
# pyrsistent                    0.17.3
# python-daemon                 2.3.0
# python-dateutil               2.8.1
# python-etcd                   0.4.5
# pythondialog                  3.5.1
# pytz                          2021.1
# pyvmomi                       6.5.0.2017.5.post1
# PyYAML                        5.4.1
# pyzmq                         22.0.3
# requests                      2.25.1
# requests-oauthlib             1.3.0
# requests-toolbelt             0.9.1
# rok-common                    1.2rc0.post0+295.g622fe91aca
# rok-etcd-client               1.2rc0.post0+295.g622fe91aca
# rok-gw-client                 1.2rc0.post0+295.g622fe91aca
# rok-kubernetes                1.2rc0.post0+295.g622fe91aca
# rok-tasks                     1.2rc0.post0+295.g622fe91aca
# rsa                           4.7.2
# scikit-learn                  0.24.2
# scipy                         1.5.4
# Send2Trash                    1.5.0
# serpent                       1.30.2
# setuptools                    54.2.0
# simplejson                    3.17.2
# six                           1.15.0
# sklearn                       0.0
# snowballstemmer               2.1.0
# Sphinx                        3.5.4
# sphinxcontrib-applehelp       1.0.2
# sphinxcontrib-devhelp         1.0.2
# sphinxcontrib-htmlhelp        1.0.3
# sphinxcontrib-jsmath          1.0.1
# sphinxcontrib-qthelp          1.0.3
# sphinxcontrib-serializinghtml 1.1.4
# strip-hints                   0.1.9
# table-logger                  0.3.6
# tabulate                      0.8.9
# termcolor                     1.1.0
# terminado                     0.9.4
# testpath                      0.4.4
# threadpoolctl                 2.2.0
# tornado                       6.1
# traitlets                     4.3.3
# typing-extensions             3.7.4.3
# tzlocal                       2.1
# udatetime                     0.0.16
# unicodecsv                    0.14.1
# uritemplate                   3.0.1
# urllib3                       1.26.4
# wcwidth                       0.2.5
# webencodings                  0.5.1
# websocket-client              0.58.0
# wheel                         0.30.0
# widgetsnbextension            3.5.1
# wrapt                         1.12.1
# zipp                          3.4.1
# WARNING: You are using pip version 21.0.1; however, version 21.2.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.

# %%
import sklearn
print(sklearn.__version__)
# Out:
# 0.24.2

# %%
import scikit-learn
print(scikit-learn.__version__)
# Out:
#   File "<ipython-input-10-6ba52cd5e01e>", line 1
#     import scikit-learn
#                  ^
# SyntaxError: invalid syntax
